# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 20,10
# calculate summary stats

# %%
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from numpy import var
from numpy import std

# %%
# seed the random number generator
seed(1)
# generate univariate observations
data = 5 * randn(10000) #+ 50

# calculate statistics
print(f'Mean: {mean(data)}' )
print(f'Variance: {var(data)}')
print(f'Standard Deviation: {std(data)}')
# Out:
# Mean: 0.04886328349552483
# Variance: 24.939329038791165
# Standard Deviation: 4.9939292184402415

# %%
fig = plt.figure()

axis_1 = fig.add_subplot(131)
axis_2 = fig.add_subplot(133)

axis_1.hist(data)
axis_2.hist(data * 1000)

plt.show()
